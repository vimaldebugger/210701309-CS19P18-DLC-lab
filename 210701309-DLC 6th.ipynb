# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Generate dummy sequential data
def generate_data(num_samples=1000, sequence_length=10, num_classes=2):
    X = np.random.rand(num_samples, sequence_length, 1)  # 3D input for RNN
    y = np.random.randint(num_classes, size=(num_samples, num_classes))  # One-hot encoded labels
    return X, y

X, y = generate_data()

# %%
model = keras.Sequential([
    layers.SimpleRNN(50, activation='relu', input_shape=(X.shape[1], X.shape[2])),
    layers.Dense(2, activation='softmax')  # Adjust the number of units for your classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(X, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2890 - loss: 0.7011
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3717 - loss: 0.6955
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3133 - loss: 0.6898
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4061 - loss: 0.7028
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3682 - loss: 0.7140
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4671 - loss: 0.6991
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5610 - loss: 0.6979
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5365 - loss: 0.6840
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4673 - loss: 0.7151
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4358 - loss: 0.7217

# %%
# Generate test data
X_test, y_test = generate_data(num_samples=200)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7345 - loss: 0.7880
# Test Accuracy: 0.7150

# %%
# Generate some new data for prediction
X_new = np.random.rand(5, 10, 1)  # 5 new samples
predictions = model.predict(X_new)
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# [[0.5707015  0.42929852]
#  [0.73506457 0.26493546]
#  [0.41206312 0.5879369 ]
#  [0.77947986 0.22052018]
#  [0.72458905 0.27541092]]
